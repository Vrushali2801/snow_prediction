# %%
import google.auth
from google.cloud import bigquery

creds, detected_project = google.auth.default()
print("Detected project:", detected_project) 

PROJECT_ID = "learnings-challenge-470222"
client = bigquery.Client(project=PROJECT_ID)
client.query("SELECT 1").result()
print("BigQuery client OK")
# Out:
# Detected project: learnings-challenge-470222
# BigQuery client OK

# %%
# %load_ext bigquery_magics

# %%
# %%bigquery
# SELECT *
# FROM `bigquery-public-data.samples.gsod`
# LIMIT 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    station_number  wban_number  year  month  day  mean_temp  \
# 0           36010        99999  1929     12    6  49.500000
# 1           36010        99999  1929     10    7  53.200001
# 2           38940        99999  1929     10   14  53.000000
# 3           33790        99999  1929     10   18  46.799999
# 4           30750        99999  1929     11   24  46.700001
# 5           30050        99999  1929     12    1  45.700001
# 6           38940        99999  1929     11   29  54.200001
# 7           33790        99999  1929     10    3  52.500000
# 8           33110        99999  1929     10   28  52.200001
# 9           32620        99999  1929     11    3  44.599998
#
#    num_mean_temp_samples  mean_dew_point  num_mean_dew_point_samples  \
# 0                      4       47.500000                           4
# 1                      4       49.099998                           4
# 2                      4       50.700001                           4
# 3                      4       41.500000                           4
# 4                      4       43.200001                           4
# 5                      4       42.799999                           4
# 6                      4       51.799999                           4
# 7                      4       39.299999                           4
# 8                      4       47.299999                           4
# 9                      5       40.599998                           4
#
#    mean_sealevel_pressure  ...  min_temperature  min_temperature_explicit  \
# 0              983.200012  ...              NaN                      <NA>
# 1             1002.299988  ...              NaN                      <NA>
# 2             1030.699951  ...              NaN                      <NA>
# 3             1009.200012  ...              NaN                      <NA>
# 4              989.000000  ...              NaN                      <NA>
# 5              991.599976  ...              NaN                      <NA>
# 6             1001.000000  ...              NaN                      <NA>
# 7              998.599976  ...              NaN                      <NA>
# 8             1003.400024  ...              NaN                      <NA>
# 9             1021.200012  ...              NaN                      <NA>
#
#    total_precipitation  snow_depth    fog   rain   snow   hail  thunder  \
# 0                  NaN         NaN  False  False  False  False    False
# 1                  NaN         NaN  False  False  False  False    False
# 2                 0.00         NaN  False  False  False  False    False
# 3                 0.00         NaN  False  False  False  False    False
# 4                 0.00         NaN  False  False  False  False    False
# 5                  NaN         NaN  False  False  False  False    False
# 6                  NaN         NaN  False  False  False  False    False
# 7                 0.00         NaN  False  False  False  False    False
# 8                  NaN         NaN  False  False  False  False    False
# 9                 0.01         NaN  False  False  False  False    False
#
#    tornado
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
#
# [10 rows x 31 columns]

# %%
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

today = datetime.today()
target_date = today - relativedelta(years=20) + timedelta(days=1)
target_date_str = target_date.strftime("%Y-%m-%d")
target_date_str
# Out:
# '2005-08-29'
